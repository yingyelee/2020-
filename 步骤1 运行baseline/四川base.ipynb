# %%
# coding=utf-8
'''
Created on 2020年6月5日

@author: LSH
'''
import os
import gc
import time
import psutil
import datetime
import numpy as np
import pandas as pd
import lightgbm as lgb
import pyarrow.parquet as pq
from gensim.models import Word2Vec
from collections import defaultdict
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score
from sklearn.metrics import f1_score
from scipy.stats import entropy, pearsonr, stats
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
pd.set_option('display.unicode.ambiguous_as_wide', True)
pd.set_option('display.unicode.east_asian_width', True)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option("display.max_colwidth",100)
pd.set_option('display.width',1000)
path = r"H:\compitition\sichuan/"
user_data = r"H:\compitition\sichuan\train/"

 
def get_app_feats(df):
    print(df.head())
    print(df["busi_name"].value_counts())
    phones_app = df[["phone_no_m"]].copy()
    phones_app = phones_app.drop_duplicates(subset=['phone_no_m'], keep='last')
    tmp = df.groupby("phone_no_m")["busi_name"].agg(busi_count="nunique")
    phones_app = phones_app.merge(tmp, on="phone_no_m", how="left")
    """使用的流量统计
    """
    tmp = df.groupby("phone_no_m")["flow"].agg(flow_mean="mean", 
                                               flow_median = "median", 
                                               flow_min  = "min", 
                                               flow_max = "max", 
                                               flow_var = "var",
                                               flow_sum = "sum")
    phones_app = phones_app.merge(tmp, on="phone_no_m", how="left")
    tmp = df.groupby("phone_no_m")["month_id"].agg(month_ids ="nunique")
    phones_app = phones_app.merge(tmp, on="phone_no_m", how="left")
    #月流量使用统计
    phones_app["flow_month"] = phones_app["flow_sum"] / phones_app["month_ids"]

    return phones_app


def get_voc_feat(df):
    df["start_datetime"] = pd.to_datetime(df['start_datetime'] )
    df["hour"] = df['start_datetime'].dt.hour
    df["day"] = df['start_datetime'].dt.day
    print(df.head())
    phone_no_m = df[["phone_no_m"]].copy()
    phone_no_m = phone_no_m.drop_duplicates(subset=['phone_no_m'], keep='last')
    #对话人数和对话次数
    tmp = df.groupby("phone_no_m")["opposite_no_m"].agg(opposite_count="count", opposite_unique="nunique")
    phone_no_m = phone_no_m.merge(tmp, on="phone_no_m", how="left")
    """主叫通话
    """
    df_call = df[df["calltype_id"]==1].copy()
    tmp = df_call.groupby("phone_no_m")["imei_m"].agg(voccalltype1="count", imeis="nunique")
    phone_no_m = phone_no_m.merge(tmp, on="phone_no_m", how="left")
    phone_no_m["voc_calltype1"] = phone_no_m["voccalltype1"] / phone_no_m["opposite_count"] 
    tmp = df_call.groupby("phone_no_m")["city_name"].agg(city_name_call="nunique")
    phone_no_m = phone_no_m.merge(tmp, on="phone_no_m", how="left")
    tmp = df_call.groupby("phone_no_m")["county_name"].agg(county_name_call="nunique")
    phone_no_m = phone_no_m.merge(tmp, on="phone_no_m", how="left")
    
    """和固定通话者的对话统计
    """
    tmp = df.groupby(["phone_no_m","opposite_no_m"])["call_dur"].agg(count="count", sum="sum")
    phone2opposite = tmp.groupby("phone_no_m")["count"].agg(phone2opposite_mean="mean", phone2opposite_median="median", phone2opposite_max="max")
    phone_no_m = phone_no_m.merge(phone2opposite, on="phone_no_m", how="left")
    phone2opposite = tmp.groupby("phone_no_m")["sum"].agg(phone2oppo_sum_mean="mean", phone2oppo_sum_median="median", phone2oppo_sum_max="max")
    phone_no_m = phone_no_m.merge(phone2opposite, on="phone_no_m", how="left")
    
    """通话时间长短统计
    """
    tmp = df.groupby("phone_no_m")["call_dur"].agg(call_dur_mean="mean", call_dur_median="median", call_dur_max="max", call_dur_min="min")
    phone_no_m = phone_no_m.merge(tmp, on="phone_no_m", how="left")
    
    tmp = df.groupby("phone_no_m")["city_name"].agg(city_name_nunique="nunique")
    phone_no_m = phone_no_m.merge(tmp, on="phone_no_m", how="left")
    tmp = df.groupby("phone_no_m")["county_name"].agg(county_name_nunique="nunique")
    phone_no_m = phone_no_m.merge(tmp, on="phone_no_m", how="left")
    tmp = df.groupby("phone_no_m")["calltype_id"].agg(calltype_id_unique="nunique")
    phone_no_m = phone_no_m.merge(tmp, on="phone_no_m", how="left")
    
    """通话时间点偏好
    """
    tmp = df.groupby("phone_no_m")["hour"].agg(voc_hour_mode = lambda x:stats.mode(x)[0][0], 
                                               voc_hour_mode_count = lambda x:stats.mode(x)[1][0], 
                                               voc_hour_nunique="nunique")
    phone_no_m = phone_no_m.merge(tmp, on="phone_no_m", how="left")
    
    tmp = df.groupby("phone_no_m")["day"].agg(voc_day_mode = lambda x:stats.mode(x)[0][0], 
                                               voc_day_mode_count = lambda x:stats.mode(x)[1][0], 
                                               voc_day_nunique="nunique")
    phone_no_m = phone_no_m.merge(tmp, on="phone_no_m", how="left")
    return phone_no_m


def get_sms_feats(df):
    print(df.head())
    df['request_datetime'] = pd.to_datetime(df['request_datetime'] )
    df["hour"] = df['request_datetime'].dt.hour
    df["day"] = df['request_datetime'].dt.day
#     df["month"] = df['request_datetime'].dt.month

    phone_no_m = df[["phone_no_m"]].copy()
    phone_no_m = phone_no_m.drop_duplicates(subset=['phone_no_m'], keep='last')
    #对话人数和对话次数
    tmp = df.groupby("phone_no_m")["opposite_no_m"].agg(sms_count="count", sms_nunique="nunique")
    tmp["sms_rate"] = tmp["sms_count"]/tmp["sms_nunique"]
    phone_no_m = phone_no_m.merge(tmp, on="phone_no_m", how="left")
    """短信下行比例
    """
    calltype2 = df[df["calltype_id"]==2].copy()
    calltype2 = calltype2.groupby("phone_no_m")["calltype_id"].agg(calltype_2="count")
    phone_no_m = phone_no_m.merge(calltype2, on="phone_no_m", how="left")
    phone_no_m["calltype_rate"] = phone_no_m["calltype_2"] / phone_no_m["sms_count"]
    """短信时间
    """
    tmp = df.groupby("phone_no_m")["hour"].agg(hour_mode = lambda x:stats.mode(x)[0][0], 
                                               hour_mode_count = lambda x:stats.mode(x)[1][0], 
                                               hour_nunique="nunique")
    phone_no_m = phone_no_m.merge(tmp, on="phone_no_m", how="left")
    
    tmp = df.groupby("phone_no_m")["day"].agg(day_mode = lambda x:stats.mode(x)[0][0], 
                                               day_mode_count = lambda x:stats.mode(x)[1][0], 
                                               day_nunique="nunique")
    phone_no_m = phone_no_m.merge(tmp, on="phone_no_m", how="left")
    
    return phone_no_m
    
    
    
    
def train_model():
    test_app_feat=pd.read_csv(user_data+'test_app_feat.csv')
    test_voc_feat=pd.read_csv(user_data+'test_voc_feat.csv')
    test_sms_feat=pd.read_csv(user_data + "test_sms_feat.csv")
    test_user=pd.read_csv(path+'test/test_user.csv')
    test_user = test_user.merge(test_app_feat, on="phone_no_m", how="left")
    test_user = test_user.merge(test_voc_feat, on="phone_no_m", how="left")
    test_user = test_user.merge(test_sms_feat, on="phone_no_m", how="left")
    test_user["city_name"] = LabelEncoder().fit_transform(test_user["city_name"].astype(np.str))
    test_user["county_name"] = LabelEncoder().fit_transform(test_user["county_name"].astype(np.str))
    
    train_app_feat = pd.read_csv(user_data + "train_app_feat.csv")
    train_voc_feat = pd.read_csv(user_data + "train_voc_feat.csv")
    train_sms_feat=pd.read_csv(user_data + "train_sms_feat.csv")
    train_user=pd.read_csv(path+'train/train_user.csv')
    drop_r = ["arpu_201908","arpu_201909","arpu_201910","arpu_201911","arpu_201912","arpu_202001","arpu_202002"]
    train_user.drop(drop_r, axis=1,inplace=True)
    train_user.rename(columns={"arpu_202003":"arpu_202004"},inplace=True)
    train_user = train_user.merge(train_app_feat, on="phone_no_m", how="left")
    train_user = train_user.merge(train_voc_feat, on="phone_no_m", how="left")
    train_user = train_user.merge(train_sms_feat, on="phone_no_m", how="left")
    train_user["city_name"] = LabelEncoder().fit_transform(train_user["city_name"].astype(np.str))
    train_user["county_name"] = LabelEncoder().fit_transform(train_user["county_name"].astype(np.str))

    sub = test_user[["phone_no_m"]].copy()
    
    params = {
    'objective': 'binary',
    'metric': 'auc',
    'num_leaves': 31,
    'max_bin': 50,
    'max_depth': 6,
    "learning_rate":0.02,
    "colsample_bytree":0.8,#每次迭代中随机选择特征的比例
    "bagging_fraction":0.8, #每次迭代时用的数据比例
    'min_child_samples': 25,
    'n_jobs': -1,
    'silent': True,    #信息输出设置成1则没有信息输出
    'seed':1000,
    }
    train_label = train_user[["label"]].copy()
    print(np.sum(train_label), train_label.shape, train_label.head())
    
    test_user.drop(["phone_no_m"], axis=1,inplace=True)
    train_user.drop(["phone_no_m", "label"], axis=1,inplace=True)
    kf = StratifiedKFold(n_splits = 5, shuffle=True, random_state=1024)
    test_p = []
    threshold = 0
    scores = 0
    for i, (train_index, vaild_index) in enumerate(kf.split(train_user, train_label["label"])):
#         print('第{}次训练...'.format(i+1))
        train_x = train_user.iloc[train_index]
        train_y = train_label.iloc[train_index]
        valid_x = train_user.iloc[vaild_index]
        valid_y = train_label.iloc[vaild_index]
        
        cat = ["city_name", "county_name"]
        lgb_train = lgb.Dataset(train_x, train_y, categorical_feature=cat, silent=True)
        lgb_eval = lgb.Dataset(valid_x, valid_y, reference=lgb_train, categorical_feature=cat, silent=True)
        
        gbm = lgb.train(params, lgb_train, num_boost_round=1000, valid_sets=[lgb_train,lgb_eval], verbose_eval=100, early_stopping_rounds=200)
    
        vaild_preds = gbm.predict(valid_x, num_iteration=gbm.best_iteration)
        bp, bestf1= score_vail(vaild_preds, valid_y)
        print("score: ", bestf1 , bp)
        scores += bestf1
        threshold += bp
        ##sauc = myFevalAuc(vaild_preds, valid_y)
        importance = gbm.feature_importance()
        feature_name = gbm.feature_name()
        feature_importance = pd.DataFrame({'feature_name':feature_name,'importance':importance} ).sort_values(by='importance',ascending=False)
        feature_importance.to_csv('feature_importance11.csv',index=None,encoding='utf-8-sig')
        test_pre = gbm.predict(test_user, num_iteration=gbm.best_iteration)
        test_pre = MinMaxScaler().fit_transform(test_pre.reshape(-1, 1))
        test_pre = test_pre.reshape(-1, )
        test_p.append(test_pre)
    threshold = threshold/len(test_p)
    print(threshold)
    print("五折平均分数: ", scores/len(test_p))
    test_p = np.array(test_p)
    test_p = test_p.mean(axis=0)
    sub["prob"] = test_p
    sub["label"] = sub["prob"] > round(np.percentile(sub["prob"], threshold), 4)
    sub[["phone_no_m", "label"]].to_csv('submission630.csv', index=False,encoding='utf-8') 
    train_user.to_csv('train_user4.csv', index=False,encoding='utf-8')
    test_user.to_csv('test_user4.csv', index=False,encoding='utf-8')


def score_vail(vaild_preds, real):
    """f1阈值搜索
    """
#     import matplotlib.pylab as plt
#     plt.figure(figsize=(16,5*10))
    best = 0
    bp = 0
    score = []
    for i in range(600):
        p = 32+i*0.08
        threshold_test = round(np.percentile(vaild_preds, p), 4)
        pred_int = vaild_preds>threshold_test
        ff = f1_score(pred_int,real)
        score.append(ff)
        
        if ff>=best:
            best = ff
            bp = p
#     plt.plot(range(len(score)), score)
#     plt.show()
    return bp, best


def feats():
    test_voc=pd.read_csv(path+'test/test_voc.csv',)
    test_voc_feat = get_voc_feat(test_voc)
    test_voc_feat.to_csv(user_data + "test_voc_feat.csv", index=False)

    test_app=pd.read_csv(path+'test/test_app.csv',)
    test_app_feat = get_app_feats(test_app)
    test_app_feat.to_csv(user_data + "test_app_feat.csv", index=False)
    
    test_sms=pd.read_csv(path+'test/test_sms.csv',)
    test_sms_feat = get_sms_feats(test_sms)
    test_sms_feat.to_csv(user_data + "test_sms_feat.csv", index=False)
     
    train_voc=pd.read_csv(path+'train/train_voc.csv',)
    train_voc_feat = get_voc_feat(train_voc)
    train_voc_feat.to_csv(user_data + "train_voc_feat.csv", index=False)

    train_app=pd.read_csv(path+'train/train_app.csv',)
    train_app_feat = get_app_feats(train_app)
    train_app_feat.to_csv(user_data + "train_app_feat.csv", index=False)

    train_sms=pd.read_csv(path+'train/train_sms.csv',)
    train_sms_feat = get_sms_feats(train_sms)
    train_sms_feat.to_csv(user_data + "train_sms_feat.csv", index=False)


if __name__ == "__main__":
    print("start")
    
    feats()
    train_model()
# Out:
# start
#                                                                                             phone_no_m                                                                                        opposite_no_m  calltype_id      start_datetime  call_dur city_name county_name                                                                                               imei_m  hour  day
# 0  b3dce36871f3e88164b18d4953b114163f008cb51c28fe932ae3c734f3b1d1e2853d63fb3fb52a09fd9d0997b64fe579...  f87f526ee776ac8b6b28392620fbb6049af9eaadab7de2ee9d7c5a31d7404566b8a3c25f404f793e513448a8c5dad194...            1 2020-04-13 21:04:10      1909       NaN         NaN  685a0bfcd91b4ecec2ff35d656a35a4e4f9e1c7a92b15f5c3c0675fcf8b6c9adc35731ab15e91401f2367f1d9d2910f9...    21   13
# 1  b3dce36871f3e88164b18d4953b114163f008cb51c28fe932ae3c734f3b1d1e2853d63fb3fb52a09fd9d0997b64fe579...  f87f526ee776ac8b6b28392620fbb6049af9eaadab7de2ee9d7c5a31d7404566b8a3c25f404f793e513448a8c5dad194...            1 2020-04-13 18:32:50      2510       NaN         NaN  685a0bfcd91b4ecec2ff35d656a35a4e4f9e1c7a92b15f5c3c0675fcf8b6c9adc35731ab15e91401f2367f1d9d2910f9...    18   13
# 2  b3dce36871f3e88164b18d4953b114163f008cb51c28fe932ae3c734f3b1d1e2853d63fb3fb52a09fd9d0997b64fe579...  f87f526ee776ac8b6b28392620fbb6049af9eaadab7de2ee9d7c5a31d7404566b8a3c25f404f793e513448a8c5dad194...            1 2020-04-13 19:55:12        25       NaN         NaN  685a0bfcd91b4ecec2ff35d656a35a4e4f9e1c7a92b15f5c3c0675fcf8b6c9adc35731ab15e91401f2367f1d9d2910f9...    19   13
# 3  7ec68a368fbbec3279a6a34847f7959623dbff4638351aa0c4ef3e6c719a4cce873e332d11c2c8f860a67edcc4bc3706...  ed8280e5590e40e35a2af7d8708a0754540b0612600d5255b8b79e576d1543765e552e30cb50aae3f4d424e08e8104a8...            1 2020-04-20 14:11:44       276       NaN         NaN  a60e82a4383faa79ea972adc48686a729f689b7d1923bce82ca67c7deae306fec30004b30260b56e13d77f7912712225...    14   20
# 4  7ec68a368fbbec3279a6a34847f7959623dbff4638351aa0c4ef3e6c719a4cce873e332d11c2c8f860a67edcc4bc3706...  ba792e76c3e7ee47d2403083f6def313372ae450ddf0b946d2f3d237e05cd99e75265be9d91ce58bc149919c97e1355f...            2 2020-04-20 12:56:33       539       NaN         NaN  a60e82a4383faa79ea972adc48686a729f689b7d1923bce82ca67c7deae306fec30004b30260b56e13d77f7912712225...    12   20
#                                                                                             phone_no_m busi_name        flow month_id
# 0  2abe25ed833883fcb81fb9f987596af936a7ef922c8d1de33415928ae5c5a5fce06e92e805cb08676a3dd6554a01c1c7...       NaN   72.853565  2020-04
# 1  2abe25ed833883fcb81fb9f987596af936a7ef922c8d1de33415928ae5c5a5fce06e92e805cb08676a3dd6554a01c1c7...        QQ   34.665351  2020-04
# 2  2abe25ed833883fcb81fb9f987596af936a7ef922c8d1de33415928ae5c5a5fce06e92e805cb08676a3dd6554a01c1c7...      旺信    1.575969  2020-04
# 3  2abe25ed833883fcb81fb9f987596af936a7ef922c8d1de33415928ae5c5a5fce06e92e805cb08676a3dd6554a01c1c7...      微信  664.393780  2020-04
# 4  2abe25ed833883fcb81fb9f987596af936a7ef922c8d1de33415928ae5c5a5fce06e92e805cb08676a3dd6554a01c1c7...      钉钉    0.025555  2020-04
# DNS                                   2072
# 微信                                  1740
# 腾讯网                                1546
# QQ                                    1369
# 高德导航                              1313
# 手机百度                              1252
# 腾讯新闻                              1227
# 淘宝                                  1212
# 网页浏览                              1194
# 今日头条                              1141
# 百度地图                              1120
# HTTPS                                 1060
# 网易网                                1046
# 腾讯地图                              1017
# NTP                                    982
# 支付宝                                 965
# SSL                                    964
# QQ浏览器                               961
# 腾讯视频                               912
# 腾讯软件中心                           907
# 友盟+                                  883
# 阿里云                                 879
# 旺信                                   871
# 谷歌应用                               860
# YouTube视频                            846
# 中国移动账户管理中心和通行证门户       843
# 抖音                                   808
# qq空间                                 788
# 百度搜索                               786
# WeiXin_Pay_Action                      776
# 阿里巴巴服务                           776
# 拼多多                                 760
# UC浏览器                               757
# MmStat                                 729
# 应用宝                                 723
# SSDP                                   702
# RTP                                    680
# 京东                                   671
# 小米服务                               668
# 钞针系统                               665
# Qchannel                               665
# 360安全卫士                            664
# HTTP2                                  664
# 新浪网                                 657
# STUN                                   652
# 搜狗搜索                               644
# 火山小视频                             641
# 腾讯灯塔                               630
# Behavior                               616
# CNZZ统计                               610
# 华为应用市场                           601
# 彩信                                   600
# 北京字节跳动科技有限公司               595
# 个推                                   591
# FXLTSBL                                591
# 天猫                                   588
# JPush                                  585
# 腾讯云                                 570
# Google Analytics                       562
# QQ音乐                                 552
# XiGuaShiPin                            531
# Crashlytics网络协议                    517
# BaiDuTongJi                            511
# 优酷                                   510
# XiGuaShiPin_HTTP_Video                 504
# 百度新闻                               498
# 魅族应用中心                           477
# Tanx                                   465
# 财付通                                 454
# 快手动漫                               451
# 爱奇艺视频                             450
# 搜狗输入法                             449
# 新浪微博                               445
# 国双                                   441
# 网宿科技                               419
# RTCP                                   417
# AdMaster精硕科技                       413
# 银联网上银行                           409
# ShareSDK                               409
# MySpace                                407
# 美团                                   404
# 搜狐网                                 395
# 华为网盘                               390
# 讯飞语音云                             376
# 大众点评                               366
# 武汉安天信息技术有限责任公司           360
# Vivo官网                               360
# 滴滴出行                               351
# Qzone                                  349
# NetBios                                348
# 华为商城                               346
# WiFI万能钥匙                           344
# 微视                                   340
# Facebook                               337
# 有赞网                                 337
# 苹果地图                               336
# TalkingData                            334
# 钉钉                                   332
# 百度视频                               332
# 七牛                                   330
# QQ旋风                                 330
# ICY                                    320
# 华为桌面云                             319
# 凤凰电台                               319
# Teddymobile                            316
# 酷狗音乐                               309
# ChinaGovSites                          308
# appjiagu网                             306
# SIP Control                            298
# OPPO公共服务                           296
# QQ同步助手                             295
# 搜狐视频                               292
# ITunes                                 292
# RTMFP                                  287
# Cloudflare                             277
# 苹果服务                               277
# VIVO应用商店                           270
# DoubleClick广告                        270
# QQ阅读                                 269
# 好看视频                               269
# 华为服务                               268
# 中国天气通                             268
# 王者荣耀                               268
# QQ游戏                                 266
# 听云                                   264
# IOS PushMessage                        261
# MIS系统                                261
# 小米商城                               260
# 中国移动应用                           259
# 139邮箱                                258
# 神马搜索                               257
# 加和科技                               256
# 3GPP                                   255
# 百度知道                               255
# FengKongCloud                          253
# 快手                                   250
# 微云                                   250
# wifi万能钥匙广告系统                   250
# 爱奇艺PPS                              248
# Bootcss                                248
# 一点资讯                               246
# 农行掌上银行                           245
# Appsflyer                              245
# AppleiCloud                            243
# Apple Siri                             242
# 百度钱包                               242
# QQ TongXunLu                           239
# QQ邮箱                                 237
# 58同城                                 236
# iMessage                               235
# 品友互动                               234
# WAP2                                   232
# Digicert证书校验网站                   232
# Shuzilm                                232
# TengYunTianXia                         230
# Izatcloud                              228
# 易企秀                                 228
# 百度贴吧                               227
# QQ商店                                 225
# AppleCertificate                       224
# AiTingZhuoYue                          216
# 中国工商银行                           213
# WangShangYinHang                       211
# 平安服务                               210
# 亚马逊购物                             210
# AppleID Login                          210
# QQ群                                   204
# 蜻蜓FM                                 202
# NeiXin                                 201
# 中国建设银行                           201
# 掌阅iReader                            200
# 中国电信营业厅                         200
# Coloros                                197
# Growingio                              196
# oppo应用商店                           196
# LeBoTouPing                            196
# GoogleAdsense                          191
# Find My Friends                        190
# 知乎                                   188
# 触宝                                   187
# NearMe云笔记                           187
# 网易云音乐                             186
# 百度糯米                               185
# 百度网盘                               184
# 最美天气                               183
# Imtmp                                  181
# 起点读书                               180
# 天气频道                               180
# Ksmobile                               179
# HereMap                                173
# KuGouZhiBo                             173
# 百度百科                               172
# ShouQianBa                             171
# 腾讯微博                               171
# 信析宝                                 170
# 金山网络                               167
# YahooSearch                            167
# Telegram                               165
# WangYiQiYu                             165
# AppStore                               164
# 喜马拉雅听                             164
# LianShangDuShu                         163
# 沃邮箱                                 162
# ShuiDiChou                             161
# WPS Office                             161
# 同程旅游                               160
# Godaddy                                157
# Scrcu                                  155
# 人民网                                 154
# FengDongcdn                            154
# 九游                                   153
# 百度文库                               152
# 喔噻                                   152
# 携程旅行                               150
# 豌豆荚                                 149
# XYCDN_Other                            149
# 美图秀秀                               147
# 联发科芯片科技                         146
# 金山办事处                             145
# Openinstall                            145
# GlobalSign                             144
# 哔哩哔哩动画                           144
# CaiNiaoGuoGuo                          142
# 中国青年网                             140
# TongDun                                140
# 米聊                                   139
# 全民K歌                                138
# MDNS                                   137
# CIBN互联网电视官网                     137
# 苏宁易购                               136
# 步步高集团                             133
# LkMe                                   131
# 快的打车                               130
# 融云即时通讯云                         128
# 饿了么                                 128
# PP助手                                 127
# 小红书海外购物神器                     127
# 小米应用商店                           126
# Usertrust                              126
# BeiKe                                  123
# 京东金融                               122
# 我要啦                                 119
# NOW直播                                118
# 环球时报                               118
# 聚胜万合                               116
# Unity3D                                116
# 360云盘                                116
# Jabber                                 116
# 迅游                                   115
# 酷6视频                                115
# 腾讯动漫                               114
# Sina_WeiBo_HTTP_Video                  114
# 腾讯手机管家                           112
# 360搜索                                112
# 绝地求生社区                           112
# 极验验证码                             111
# BitTorrent                             110
# Other VoIP                             110
# DaYu                                   107
# 秒拍                                   107
# 唯品会                                 107
# WenJuanXing                            106
# 谷歌安全卫士                           105
# 沃TV                                   105
# CM Security                            105
# QIYIReader                             105
# Meitustat                              104
# 迅雷                                   103
# 众安保险                               102
# 麦当劳麦乐送                           101
# 百度网址大全                           101
# Twitter                                100
# 公安部交通安全综合服务管理平台         100
# HelloBike                               99
# Sobot                                   97
# Sf Express                              96
# Facetime                                96
# 金山云                                  96
# InMobi广告                              95
# Eastday                                 95
# 酷我音乐                                94
# QQFTN                                   94
# 网易新闻                                94
# 虎牙直播                                93
# UC影音                                  93
# 豆瓣小组                                93
# Mookie1                                 92
# Rayjump                                 91
# 招商银行                                91
# QQ飞车                                  91
# Flurry                                  90
# 对吧                                    90
# TencentClass                            90
# 美拍                                    90
# AliGames                                90
# 开心消消乐                              89
# 艺龙                                    89
# ShuiYinXiangJi                          89
# Shobserver                              88
# 360JieTiao                              87
# 猎豹清理大师                            87
# 歪歪                                    87
# 芒果TV                                  86
# 陌陌                                    85
# ICBCRongELian                           84
# Zalo                                    84
# Comodoca                                83
# Kakao Talk                              82
# MS Common                               82
# 汽车之家                                81
# 小米路由器                              81
# 有道词典                                81
# AliBaBaCaiGou                           80
# 新浪新闻                                79
# 搜狐新闻                                79
# JingDongQianBao                         77
# TianTianKuaiBao                         77
# 热云                                    76
# 飞聊                                    76
# 人民日报                                75
# Skype                                   75
# AndroidConCheck                         74
# Aiclk                                   74
# AccuWeather                             74
# 中国银行手机银行                        73
# 安居客                                  73
# Levect                                  73
# Xiaoka                                  72
# qq voice                                72
# Hangouts环聊                            72
# 多益网络                                71
# 聚美优品                                71
# TianYiCloudService                      71
# etoote                                  70
# 作业帮                                  70
# 易观集团                                70
# 各种广告                                68
# 风行                                    68
# 交通银行                                68
# 云系统                                  68
# 搜狐快站                                67
# Dftoutiao                               67
# Adjust                                  67
# 中国银联                                66
# 北京天润基业官网                        66
# 太平洋电脑网                            66
# 去哪儿旅行                              65
# 掌上链家                                65
# OUTLOOK邮箱                             65
# WeiZongYinHang                          65
# XueAnQuan                               64
# 探探                                    63
# 中国联通手机营业厅                      63
# 易车网                                  63
# PaiPaiKanKan                            63
# 铁路12306                               63
# 猫眼电影                                62
# HuaWeiShiPin                            62
# 表情云官网                              61
# Shuqireader                             61
# FastlyCDN                               61
# 斗鱼直播                                61
# 苹果游戏中心                            60
# 必应搜索                                60
# 灵集科技                                59
# 平安口袋银行                            59
# MiJia                                   58
# Ssports                                 58
# PP视频                                  58
# 1Rtb                                    58
# Easemob                                 58
# 百度手机助手                            57
# eMule                                   57
# 瓜子                                    57
# 华扬联众官方网站                        56
# 好网友                                  56
# WebRTC                                  56
# 咪咕                                    56
# Leancloud                               55
# Faceu激萌                               55
# 手机电视MBBMS                           55
# 腾讯公共流量                            54
# Qschou                                  54
# 海度云分析                              54
# Jquery                                  54
# ZhangShangShengHuo                      54
# 美篇                                    51
# 广州通摩信息技术有限公司                51
# 搜狗浏览器                              50
# 小年糕                                  50
# 凤凰视频                                50
# Reyun                                   50
# 玩咖欢聚                                50
# 墨迹天气                                48
# 小米视频                                48
# YumChina_Browsing                       48
# 抱抱                                    48
# 11222 cn                                47
# 谷歌搜索                                47
# LaiFeng                                 47
# MLinks                                  47
# PingAnHaoCheZhu                         46
# Lenzmx                                  46
# Geotrust                                46
# Glpals                                  46
# 新浪视频                                46
# 微店                                    46
# 1LanTV_Streaming                        45
# RTMP                                    45
# 广汽本田官网                            45
# 上海宏路数据技术股份有限公司            45
# 虾米音乐                                45
# MM商场                                  45
# 太平洋汽车网                            45
# Ppdai                                   45
# 神鬼传奇                                44
# SPDY                                    44
# 摩拜单车                                44
# 口袋E行销                               44
# Ymtracking                              44
# QiMaoReader                             43
# 翼支付                                  43
# 咪咕游戏                                43
# 深圳市微领科技有限公司                  43
# google play store                       43
# 咪咕视频                                42
# 360手机助手                             42
# 虎扑                                    42
# Coap                                    41
# 看看新闻网                              41
# 悠易互通广告                            41
# XianYu                                  41
# Base                                    41
# 美颜相机                                41
# 和飞信                                  41
# ScorecardResearch                       40
# SIGMOB                                  40
# 赛门铁克认证                            40
# Intsig                                  39
# 多玩游戏                                39
# Moatads                                 39
# 智联招聘                                39
# Cyol                                    39
# Xhamster                                39
# bilibili游戏中心                        39
# Yahoo 电子信箱                          38
# Weshine                                 38
# Adobe                                   38
# 猿辅导                                  38
# 360手机卫士                             38
# MS_Common                               37
# Apple                                   37
# 网易考拉海购                            37
# Qingsongchou                            37
# 分期购物商城                            37
# Tencentmind                             36
# AdView                                  36
# GuanZhongWang                           36
# 搜搜                                    36
# 智云众                                  36
# 英威诺                                  36
# 房天下                                  36
# B612咔叽                                36
# 新民网                                  36
# 91Muzhi                                 36
# 一起作业学生端                          35
# Msftncsi                                35
# Boss直聘                                35
# QiXiuZhiBo                              35
# 卡妞微秀                                35
# 365You                                  34
# 多看阅读                                34
# 中华万年历                              34
# 苹果固件更新                            34
# MaiDanBa                                34
# 互动通联壁纸圈                          34
# 嘀嗒拼车                                34
# Ntalker                                 34
# Bshare                                  34
# 美柚                                    33
# 张力卓个人网站                          33
# 咪咕音乐                                33
# 乐视视频                                33
# ZhangShangDaoJuCheng                    33
# Vungle                                  33
# 途虎                                    32
# 12317Wan_Browsing                       32
# ZAKER                                   32
# Ulike_Browsing                          32
# 口袋购物                                32
# 猿题库                                  32
# Zoosnet                                 32
# Akamaihd                                32
# Happyelements                           32
# 东方财富                                31
# 车轮查违章                              31
# 2345网址导航                            31
# 腾讯文学                                31
# AD调查                                  31
# 搜狗地图                                30
# 37游戏                                  30
# 珍爱网                                  30
# 旺信手机版                              30
# 龙珠直播                                30
# 七牛云存储                              30
# Conac                                   30
# 网易视频                                29
# 哆啦宝                                  29
# 寻医问药                                29
# 皮皮影视                                29
# Cloudmobi                               29
# DroidVPN                                29
# QQ斗地主                                29
# 车来了                                  28
# Windows更新                             28
# 蚂蜂窝                                  28
# WangZheRongYaoZhuShou                   28
# 屈臣氏购物网                            28
# VZuWang                                 28
# 小天才                                  28
# YFCloud                                 27
# WhosHere                                27
# XianLaiGame                             27
# AiKuCun                                 27
# XiaoMiTV                                27
# RubiconProject                          27
# 凤凰新闻                                27
# Office                                  27
# 多盟                                    26
# FengChao                                26
# Placehold                               26
# 冲浪导航                                26
# 邮箱IMAP SSL网络协议                    26
# 本地宝                                  26
# JingDongDaoJia                          26
# 蘑菇街                                  26
# EClicks                                 26
# 铃声多多                                26
# 天气网                                  25
# 麦客                                    25
# 搜房网                                  25
# 央视影音                                25
# HuaWei PushMessage                      25
# KuGouLingSheng                          25
# 豆丁书房                                25
# 下厨房                                  25
# Holla                                   25
# 移动健身教练                            25
# 疯狂猜图                                25
# 电话邦                                  25
# 中关村在线                              25
# 婚礼纪                                  25
# STongHuaShun                            25
# WuLiZiXun                               25
# Att                                     25
# 35HuLian                                25
# 前程无忧51job                           25
# 妈妈网                                  24
# Adsrvr                                  24
# 映客直播                                24
# 齐鲁壹点                                24
# 萤石                                    24
# YouLiShiPin                             24
# Mapbox                                  24
# 360影视大全                             24
# 艾客信息咨询                            24
# 奇虎壁纸                                24
# 1Qianbao                                24
# Truste                                  23
# Optimix                                 23
# 微信电话本                              23
# SnakeOff                                23
# 4399游戏盒                              23
# 三星集团                                23
# Openx                                   23
# 海峡网                                  23
# 阿里公共流量                            23
# ChinaDaily                              23
# BetaMax                                 23
# Chinaz                                  22
# Branch                                  22
# 邮储银行                                22
# 柚子街                                  22
# QQ医生                                  22
# 微爱                                    22
# Apxadtracking                           22
# QuantServe                              21
# 点点虫                                  21
# 金山毒霸                                21
# Everesttech                             21
# 互动百科                                21
# Demdex                                  21
# Cnkang                                  21
# 堆糖                                    21
# Casalemedia                             21
# 丁香园                                  21
# Pclady                                  21
# 快递1000                                21
# WindowsPhone系统推送消息                21
# Ctags                                   21
# 咪咕阅读                                21
# Pubmatic                                21
# 中华网                                  20
# 掌酷                                    20
# QianNiu_Browsing                        20
# 金融界                                  20
# 爆米花网                                20
# 百度音乐                                20
# 39健康                                  20
# 熊猫驾信                                20
# 平安好医生                              20
# PiPiXia                                 20
# 微赞                                    20
# Intel                                   20
# 53Kf                                    20
# MSN                                     20
# WuTaCam                                 20
# 兴业银行                                19
# SyncML                                  19
# 18Guanjia                               19
# 天气通                                  19
# 叮咚音乐                                19
# SkyDrive                                19
# HanJuTV                                 19
# 掌上英雄联盟                            19
# CADkantu                                19
# 领英                                    18
# TeamViewer                              18
# 家庭医生                                18
# Ampproject                              18
# 宜泊科技                                18
# 秀米                                    18
# 伊秀女性网                              18
# 移动梦网                                18
# Verisign                                18
# YangGuangHuiShengHuo                    18
# 互众广告                                18
# Applovin                                18
# APICloud 柚子科技有限公司               18
# 全球速卖通                              18
# NaTieZhiTou                             18
# 兔展                                    18
# 又拍                                    18
# MiDuReader                              18
# 和彩云                                  18
# 土豆视频                                18
# 网易邮箱                                18
# AddThis                                 18
# 三星应用商店                            18
# TapTap                                  18
# I单击                                   17
# Yahoo                                   17
# Agkn                                    17
# 小豆苗疫苗助手                          17
# Snmi                                    17
# 汤姆猫跑酷                              17
# 讯飞输入法                              17
# 边锋                                    17
# Sgcc                                    17
# vagaa                                   17
# 宝宝巴士                                17
# 宝宝树孕育                              17
# HuoLaLa                                 17
# R1CDN                                   17
# 糖豆广场舞                              17
# Optimizely                              17
# 720Yun                                  17
# 股城网                                  17
# SOAP网络协议                            17
# 番茄游戏                                17
# Video加加云视链开放平台                 17
# 航旅纵横                                16
# 趣点点赚钱                              16
# WAP1                                    16
# Fring                                   16
# Shell                                   16
# IpApi                                   16
# Mpush                                   16
# 中信银行                                16
# directplay                              16
# 英语流利说                              16
# ServingSys                              16
# 民生银行                                16
# 同花顺                                  16
# QQWiFiManager                           16
# 百度公共流量                            16
# QQ麻将                                  16
# 天眼查                                  16
# WeiXinDuShu                             16
# 网速大师                                16
# 新华网                                  16
# Steam游戏平台                           16
# SheDiao                                 16
# SuYunBo                                 16
# 扫描全能王                              16
# 步步高下载中心                          16
# UC头条                                  16
# ZhuanZhuan                              16
# 好大夫在线                              15
# Kochava                                 15
# Avast Update                            15
# StarBucks                               15
# 易湃官网车易通                          15
# ZhaoLianJinRong                         15
# 清澈的水滴                              15
# Dropbox                                 15
# MiniWorld                               15
# 车168                                   15
# Cdnmaster                               15
# ip查询                                  15
# DJDuoDuo                                15
# VUEVlog                                 15
# 乐变                                    15
# 50Bang                                  15
# 穿越火线                                14
# 追追漫画                                14
# Github                                  14
# 沪江开心词场                            14
# 51AiWan                                 14
# 中国供应商                              14
# 互联星空                                14
# UIAndroid                               14
# 小猿搜题                                14
# Adnxs                                   14
# Qichacha                                14
# Newrelic                                14
# 慧聪网                                  14
# CITIC_DongKaKongJian                    14
# Ptengine                                14
# Yokagames_Browsing                      14
# 律师365                                 14
# Soul                                    14
# DtsCDN                                  14
# CMFree                                  14
# Chaoxing                                14
# D1Xz                                    14
# 驾考宝典                                14
# 精硕科技                                14
# Minecraft                               14
# Cndzys                                  14
# 星座屋                                  14
# CCZhiBo                                 13
# Showself                                13
# 酷家乐                                  13
# Ospserver                               13
# Polyv                                   13
# 135编辑器                               13
# Omtrdc                                  13
# 天涯社区                                13
# Gemius                                  13
# 银联钱包                                13
# 110Wang                                 13
# 万年历                                  13
# 艾媒网                                  13
# Cpic                                    13
# BaiDuMoTu                               13
# Mopub                                   13
# Snapchat                                13
# Histats                                 13
# NrData                                  13
# 唱吧                                    13
# 台海网                                  13
# Shangc                                  13
# Supersonicads                           13
# 欢聚云官网                              13
# Msxf                                    13
# 巨盾                                    13
# QuanMinShengHuo                         13
# Nike+Running                            13
# 码卡                                    12
# 闽南网                                  12
# Mucang                                  12
# Qlchat                                  12
# 晋江小说阅读                            12
# 斐波那契                                12
# Game Mode                               12
# 光明网                                  12
# Bootstrapcdn                            12
# Flyme                                   12
# 乐居                                    12
# 当当                                    12
# 爱卡汽车                                12
# 51Touxiang                              12
# Crwdcntrl                               12
# Soperson                                12
# 3Gmimo                                  12
# ZeGo                                    12
# 昵图网                                  12
# GeDeng                                  12
# 全国违章查询                            12
# BaiDuYueDu                              12
# BitAutoTech                             12
# Cr173                                   12
# 聚划算                                  12
# Offcn                                   12
# 中通快递官网                            12
# HuDong                                  12
# 小世界                                  12
# Statcounter                             12
# Gravatar                                12
# Suishenyun                              12
# ShiGuangXiangCe                         11
# 小世界官网                              11
# Supercell                               11
# 空中食宿                                11
# 腾讯游戏平台                            11
# PuFaXinYongKa                           11
# 万流客                                  11
# 中国新闻网                              11
# PicsArt                                 11
# 大智慧                                  11
# Innovid                                 11
# 西瓜视频                                11
# 追书神器                                11
# 和包                                    11
# ChaoXingXueXiTong                       11
# Criteo                                  11
# Szzbmy                                  11
# 积分商城                                11
# 华律网                                  11
# Pc6                                     11
# Syyx                                    11
# IP地址查询网                            11
# 顶点小说                                11
# 微软Live                                11
# Ssacdn                                  11
# 一起装修网                              11
# BlueKai                                 11
# Qqtn                                    11
# 720Static                               11
# 吆喝科技官网                            11
# 51com客户端                             11
# 融360                                   11
# 熊猫看书                                11
# SoHuGouFangZhuShou                      11
# BingMap                                 10
# SNMP                                    10
# 51YES流量统计                           10
# 六间房                                  10
# Ktvme                                   10
# Pgyer                                   10
# HuiTouTiao                              10
# MSRP                                    10
# BaiDuShare                              10
# 看准                                    10
# 好贷                                    10
# NB美的路灯                              10
# Instagram                               10
# RTSP                                    10
# 中国广播网                              10
# ZuiYou                                  10
# Xbox                                    10
# VoilloUltra                             10
# HuanXiDouDiZhu                          10
# 磨基移动广告                            10
# 店长直聘                                10
# 兑吧                                    10
# Bidswitch                               10
# Cocounion                               10
# QingMang                                10
# 追踪APP                                 10
# 曹操专车                                10
# Cntaiping                               10
# LiePin                                  10
# 法律快车                                10
# Toyota                                  10
# Wordpress                               10
# 大姨妈                                   9
# Daojia                                   9
# 运满满                                   9
# 南方财富网                               9
# JJ斗地主                                 9
# Jiathis                                  9
# Gameanalytics                            9
# XinYueJuLeBu                             9
# 晶赞广告有限公司                         9
# 纵横小说                                 9
# 巴西沃尔玛购物网站                       9
# HaiNanLiSheng_Streaming                  9
# XiaoMiYunDong                            9
# 鲁大师                                   9
# 2mdn                                     9
# 凤凰山下                                 9
# 宾谷原生广告平台                         9
# 正保远程教育                             9
# QQ中国象棋                               9
# XiaoYingLiCai                            9
# OFO共享单车                              9
# 稻壳儿                                   9
# MaiMai                                   9
# 美卓网                                   9
# JiaZhangTong                             9
# 新浪体育                                 9
# hao123上网导航                           9
# 新数网络                                 9
# Adidas                                   9
# 360免费电话                              9
# 手机加速                                 9
# 健客网                                   9
# 直播吧                                   9
# Chunyuyisheng                            9
# 学习啦                                   9
# 凡科登录管理平台                         9
# 航班管家                                 9
# 什么值得买                               9
# 澎湃新闻                                 8
# 500Caipiao                               8
# 日历官网                                 8
# 联想乐商店                               8
# Tango                                    8
# Taou                                     8
# 中华会计网校                             8
# 360Tpcdn                                 8
# Google翻译                               8
# 辣妈帮                                   8
# IE浏览器                                 8
# Qbb6                                     8
# Taoche                                   8
# Downcc                                   8
# Zendesk                                  8
# Live800                                  8
# 微话                                     8
# Ptvyun                                   8
# 英伟达                                   8
# Orange                                   8
# 光大银行                                 8
# WeiLiKanKan                              8
# Chartboost                               8
# Pp122                                    8
# ShaYuJiZhang                             8
# 爱思助手                                 8
# PPTV第一体育                             8
# 微盟                                     8
# 新东方网                                 8
# Qpgame                                   8
# QiXinBao                                 8
# Fingerflyapp                             8
# 赶集网                                   8
# Vsco                                     8
# 部落冲突                                 8
# 中国网事                                 8
# Szy                                      8
# AcFun                                    8
# Taboola                                  8
# 网易16163游戏网                          8
# CocoVoice语音通信                        8
# 球迷宝                                   8
# UCloud云计算                             8
# MediaMath                                8
# Cd120                                    8
# 小川科技                                 8
# 大象就医                                 8
# 掌游天下                                 8
# ThreeGene                                8
# 糖果网站                                 8
# 百视通                                   8
# Mvote                                    7
# Tapjoy                                   7
# 优她网                                   7
# 得到官网                                 7
# 大福星                                   7
# 荔枝FM                                   7
# 途家网                                   7
# Mozilla                                  7
# 金蝶医疗                                 7
# Viber                                    7
# 乐教乐学                                 7
# RakNetGame                               7
# LuoJiSiWei                               7
# 360Kad                                   7
# 和讯财经                                 7
# ZhangDuShuCheng                          7
# 游民星空                                 7
# 谷歌地图                                 7
# 金太阳                                   7
# 途牛旅游                                 7
# 获取奖学金公益网                         7
# Ipinfo                                   7
# 移动彩云                                 7
# YunXi                                    7
# IMO                                      7
# Amplitude                                7
# 应届毕业生求职网                         7
# Smaato                                   7
# 返利网                                   7
# 必胜客                                   7
# ViSenze                                  7
# 新商盟依                                 7
# Caiyunapp                                7
# HiLaiDian_Browsing                       7
# Scydo                                    7
# 爱拍                                     7
# Opera                                    7
# 50Zw                                     7
# 作业盒子                                 7
# Icloud邮箱                               7
# Entrust                                  7
# 开迅视频                                 7
# 国美在线                                 7
# 驾校1点通                                7
# 自贡在线                                 7
# 灵犀游戏                                 7
# 涂图                                     7
# 千帆                                     7
# Bokecc                                   7
# 我们玩                                   7
# 四川广播电视台                           7
# 微易科技                                 7
# 酷控手机遥控                             7
# 猫扑                                     7
# 挖财记账                                 7
# 职友集                                   7
# 找法网                                   7
# Ikea                                     7
# 图吧导航                                 7
# 浦发手机银行                             7
# 公务员考试                               6
# 书链                                     6
# Braze_Browsing                           6
# 云适配                                   6
# Zoom                                     6
# 酷划                                     6
# 游族网络                                 6
# Ppkao                                    6
# 新浪财经                                 6
# Bttrack                                  6
# 微俱聚                                   6
# Qnssl                                    6
# 华夏银行                                 6
# Sanfu                                    6
# 道客巴巴                                 6
# Citrix                                   6
# SMTP                                     6
# TalkingTomGoldRun                        6
# 快看漫画                                 6
# 花椒直播                                 6
# 快速问医生                               6
# 咕咚运动                                 6
# Wx co                                    6
# Localytics                               6
# 搞趣网                                   6
# 故事大全                                 6
# Chevrolet                                6
# 观察者                                   6
# Scedu                                    6
# 微商水印相机官网                         6
# 微乐游戏                                 6
# 中国人寿保险股份有限公司官网             6
# 三国鼎立                                 6
# 3G门户                                   6
# LOFTER                                   6
# 孩子王                                   6
# 56Qq                                     6
# 和讯邮箱                                 6
# 木蚂蚁                                   6
# 广西新闻网                               6
# 趣分期                                   6
# Mixpanel                                 6
# BaiShanYun                               6
# 美食天下                                 6
# 19楼                                     6
# Cncn                                     6
# 英雄游戏网站                             6
# Typekit                                  6
# 笔趣阁备用站                             6
# BinGuoXiaoXiaoXiao                       6
# 宝马官网                                 6
# 车主无忧                                 6
# BoBoShiPin                               6
# XiangCeGuanJia                           6
# 草花手游中心                             6
# KuaiMao                                  6
# 7Y7                                      6
# 陆金所                                   6
# 广发银行                                 6
# 云之家                                   6
# 词典翻译金山词霸                         6
# 华住会                                   6
# WiFi伴侣                                 5
# 追书网                                   5
# 荣耀                                     5
# 四川新闻网                               5
# 樊登读书会官网                           5
# 人人店                                   5
# 荒野行动                                 5
# 天天看看                                 5
# Daum                                     5
# Soyoung                                  5
# 凯励程官网                               5
# Segment                                  5
# 第一财经                                 5
# eBay                                     5
# 懂球帝                                   5
# Volkswagen                               5
# 网上厨房                                 5
# 凯迪网络                                 5
# Kunlun                                   5
# Shihuo                                   5
# 中金在线                                 5
# 万达电影网                               5
# Beiqingwang                              5
# 育儿网                                   5
# ...
# Maybelline                                        1
# 博客网                                            1
# Colorfy                                           1
# 妹子天空                                          1
# 本溪市威尼斯会馆娱乐有限公司                      1
# 雷霆天下                                          1
# Winner                                            1
# 安丰网                                            1
# GOMO                                              1
# Prezi                                             1
# TXT小说下载网                                     1
# Domdex                                            1
# 阜阳在线                                          1
# Oneskyapp                                         1
# Gamehao                                           1
# Vascogames                                        1
# MyPrice价格网                                     1
# Dospy                                             1
# Voluumtrk                                         1
# Op                                                1
# BipMessenger                                      1
# 瑞卡租车                                          1
# 俄亥俄州的国家杂志                                1
# 4Sale                                             1
# Algovid                                           1
# 翻牌子                                            1
# WithMe                                            1
# 太原新闻网                                        1
# Independent                                       1
# MqCDN                                             1
# Lequipe                                           1
# 随我 乐网                                         1
# 14Mp4                                             1
# Macropinch                                        1
# Opencom                                           1
# 前店后厂批发平台                                  1
# QQ华夏                                            1
# Revcontent                                        1
# 酷听网                                            1
# 最美应用                                          1
# Maribacaberita                                    1
# Gfycat                                            1
# 趣动游戏                                          1
# Polyu                                             1
# 建筑学院                                          1
# 极客学院                                          1
# 雪缘园                                            1
# Airdroid                                          1
# 福州热游网络科技有限公司                          1
# 信息浏览类网站                                    1
# Appcnt                                            1
# It com官网                                        1
# Jimcdn                                            1
# CpCDN                                             1
# 广东腾南网络信息科技有限公司                      1
# Like团                                            1
# Nidong                                            1
# 雷锋源中文网                                      1
# XingYe                                            1
# Dtac Coth                                         1
# 爱唱                                              1
# 云游控股有限公司                                  1
# 3d播播                                            1
# 微乐                                              1
# Hdporn                                            1
# Qqgexingqianming                                  1
# Cwss                                              1
# 宝软科技                                          1
# Tv5monde                                          1
# Bleacherreport                                    1
# 乐逗游戏                                          1
# Lphbs                                             1
# 电子请柬                                          1
# 优顾网                                            1
# 十牛信息科技                                      1
# Logmein                                           1
# 23文学网                                          1
# 哈狗网络技术                                      1
# Wetransfer                                        1
# UUCall电话                                        1
# 微咨询网                                          1
# HuLuWa                                            1
# WanTuLvXing                                       1
# 许愿墙                                            1
# RTMPT                                             1
# 丰趣网                                            1
# 极光推送                                          1
# LightInTheBox                                     1
# 网易微博                                          1
# 120Net                                            1
# 华丽交谈                                          1
# Marketwatc                                        1
# 卡米罗的黑暗时代                                  1
# 东华期货官网                                      1
# 传奇2                                             1
# Cosmopolitan                                      1
# Celtra                                            1
# 鼎盛军事网                                        1
# Wsi                                               1
# ShanDianShiPin                                    1
# 中国投资资讯网                                    1
# YouJie                                            1
# 25Game                                            1
# 123互联                                           1
# 乐奇网络科技                                      1
# Parse                                             1
# 7M                                                1
# 101OkeyPlus                                       1
# 青奥PEAP认证用户管理平台                          1
# 彭博商业周刊                                      1
# Spike                                             1
# Trinitigame                                       1
# Nuancemobility                                    1
# Pixiv                                             1
# CubeEscape_Game                                   1
# 趣天网                                            1
# 风车动漫                                          1
# 7Thg                                              1
# Serviporno                                        1
# Satkit                                            1
# Newsrep新闻                                       1
# 黑鸟单车官网                                      1
# 中央社网                                          1
# Yyfensi                                           1
# Tradedoubler                                      1
# 节操                                              1
# 国家基础教育资源网                                1
# 多玩约战                                          1
# Deezer                                            1
# 微信商城                                          1
# 乐享唯美时光                                      1
# Ucimg                                             1
# YandexMaps                                        1
# Coolgamebox                                       1
# Eelly                                             1
# 美术宝                                            1
# Arla                                              1
# Putao                                             1
# Ioam                                              1
# 猎奇网                                            1
# 唯嘉科技                                          1
# 亿房网                                            1
# Mobisystems                                       1
# Kissmetrics                                       1
# 妙笔阁                                            1
# Lifeselector                                      1
# Nexon                                             1
# 赛尔号                                            1
# 万界网络                                          1
# Altervista                                        1
# 呱呱洗车                                          1
# 商都网                                            1
# 可得眼镜网                                        1
# 向日葵信息科技                                    1
# Bershka                                           1
# 小牛电动                                          1
# START                                             1
# 索尼官网                                          1
# Bignox                                            1
# Kx88                                              1
# 票价网                                            1
# HolaVPN                                           1
# 力美传媒                                          1
# 课外阅读网                                        1
# Miaoxia123                                        1
# Czu                                               1
# 亚洲万里通                                        1
# AnG官网                                           1
# 香港航空                                          1
# 景坤科技官网                                      1
# 4399小游戏                                        1
# 188比分直播网                                     1
# app887应用导航                                    1
# 喊麦DJ网                                          1
# Popcorn                                           1
# Djc888                                            1
# RevolverMaps                                      1
# Emsecure                                          1
# djcc舞曲网                                        1
# 印象笔记                                          1
# resorts360度假俱乐部                              1
# 45小说网                                          1
# VideosDemadurasx                                  1
# Citymapper                                        1
# 腾讯开放云平台                                    1
# 宁波电视台                                        1
# Twist                                             1
# 18AV                                              1
# 爆笑姐夫                                          1
# 新浪秀场                                          1
# 银天下官网                                        1
# Etonline                                          1
# 爱股票                                            1
# Name: busi_name, dtype: int64
#                                                                                             phone_no_m                                                                                        opposite_no_m  calltype_id     request_datetime
# 0  0251387744988114430181c3e680a3733001a26fe686bdc1e64dfeaecd5d9e6f137df7f2a8d0a5871bcf6f371cab5bd3...  df22edbc0e3dd6bc4f2f453e687b743e8442a54834b64f06ee093a91c4a41385d46579107a443eee3ec0ce2339bcea41...            2  2019-08-01 12:13:08
# 1  0251387744988114430181c3e680a3733001a26fe686bdc1e64dfeaecd5d9e6f137df7f2a8d0a5871bcf6f371cab5bd3...  df22edbc0e3dd6bc4f2f453e687b743e8442a54834b64f06ee093a91c4a41385d46579107a443eee3ec0ce2339bcea41...            2  2019-08-01 12:13:08
# 2  0251387744988114430181c3e680a3733001a26fe686bdc1e64dfeaecd5d9e6f137df7f2a8d0a5871bcf6f371cab5bd3...  df22edbc0e3dd6bc4f2f453e687b743e8442a54834b64f06ee093a91c4a41385d46579107a443eee3ec0ce2339bcea41...            2  2019-08-01 12:13:08
# 3  296cfae1d838070c4dd05a125a85c3d29bbb95f713c2eaee0d84e7192ae0f74d47bbeb1851078c044bcf2ff919423ea8...  1205bb229d750a6bcb3f9c33893b5d68c8fc8a6443b0a7f77104587e396dc34ece1e774d2e6bb0842ea13d7d6b7983dd...            2  2019-08-01 17:46:44
# 4  39de6ef3a87b8e660e42496450c54b731f3621ca708944b2df5ae56b77968ebacddd39a6576caa7a3d8d489b75e037da...  972affd4be9e7596420379b7e7910843759cdfbd81315e753cd4ba43ea288cf33d35a2cb1ad3af35ab1bf66e4b012e4f...            2  2019-08-01 16:46:30
# label    1962
# dtype: int64 (6106, 1)    label
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.983472	valid_1's auc: 0.950997
# D:\A\lib\site-packages\lightgbm\basic.py:1205: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# D:\A\lib\site-packages\lightgbm\basic.py:741: UserWarning: silent keyword has been found in `params` and will be ignored.
# Please use silent argument of the Dataset constructor to pass this parameter.
#   .format(key))
# D:\A\lib\site-packages\lightgbm\basic.py:762: UserWarning: categorical_feature in param dict is overridden.
#   warnings.warn('categorical_feature in param dict is overridden.')
# [200]	training's auc: 0.991714	valid_1's auc: 0.954401
# [300]	training's auc: 0.996812	valid_1's auc: 0.954493
# [400]	training's auc: 0.999423	valid_1's auc: 0.955184
# [500]	training's auc: 0.999933	valid_1's auc: 0.955205
# [600]	training's auc: 0.999997	valid_1's auc: 0.955669
# [700]	training's auc: 1	valid_1's auc: 0.955549
# [800]	training's auc: 1	valid_1's auc: 0.955233
# Early stopping, best iteration is:
# [622]	training's auc: 0.999999	valid_1's auc: 0.955985
# score:  0.8917525773195876 68.64
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.980454	valid_1's auc: 0.973987
# D:\A\lib\site-packages\lightgbm\basic.py:1205: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# D:\A\lib\site-packages\lightgbm\basic.py:741: UserWarning: silent keyword has been found in `params` and will be ignored.
# Please use silent argument of the Dataset constructor to pass this parameter.
#   .format(key))
# D:\A\lib\site-packages\lightgbm\basic.py:762: UserWarning: categorical_feature in param dict is overridden.
#   warnings.warn('categorical_feature in param dict is overridden.')
# [200]	training's auc: 0.990998	valid_1's auc: 0.972689
# [300]	training's auc: 0.996589	valid_1's auc: 0.970236
# Early stopping, best iteration is:
# [103]	training's auc: 0.980776	valid_1's auc: 0.974177
# score:  0.8983957219251337 70.96000000000001
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.98215	valid_1's auc: 0.955953
# D:\A\lib\site-packages\lightgbm\basic.py:1205: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# D:\A\lib\site-packages\lightgbm\basic.py:741: UserWarning: silent keyword has been found in `params` and will be ignored.
# Please use silent argument of the Dataset constructor to pass this parameter.
#   .format(key))
# D:\A\lib\site-packages\lightgbm\basic.py:762: UserWarning: categorical_feature in param dict is overridden.
#   warnings.warn('categorical_feature in param dict is overridden.')
# [200]	training's auc: 0.992568	valid_1's auc: 0.954309
# Early stopping, best iteration is:
# [85]	training's auc: 0.978888	valid_1's auc: 0.9565
# score:  0.8755129958960328 72.24000000000001
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.981874	valid_1's auc: 0.958348
# D:\A\lib\site-packages\lightgbm\basic.py:1205: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# D:\A\lib\site-packages\lightgbm\basic.py:741: UserWarning: silent keyword has been found in `params` and will be ignored.
# Please use silent argument of the Dataset constructor to pass this parameter.
#   .format(key))
# D:\A\lib\site-packages\lightgbm\basic.py:762: UserWarning: categorical_feature in param dict is overridden.
#   warnings.warn('categorical_feature in param dict is overridden.')
# [200]	training's auc: 0.991539	valid_1's auc: 0.957836
# [300]	training's auc: 0.997566	valid_1's auc: 0.9571
# Early stopping, best iteration is:
# [142]	training's auc: 0.986438	valid_1's auc: 0.959694
# score:  0.8897959183673468 71.92
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.983741	valid_1's auc: 0.960105
# D:\A\lib\site-packages\lightgbm\basic.py:1205: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# D:\A\lib\site-packages\lightgbm\basic.py:741: UserWarning: silent keyword has been found in `params` and will be ignored.
# Please use silent argument of the Dataset constructor to pass this parameter.
#   .format(key))
# D:\A\lib\site-packages\lightgbm\basic.py:762: UserWarning: categorical_feature in param dict is overridden.
#   warnings.warn('categorical_feature in param dict is overridden.')
# [200]	training's auc: 0.992602	valid_1's auc: 0.960071
# [300]	training's auc: 0.997592	valid_1's auc: 0.960518
# [400]	training's auc: 0.999691	valid_1's auc: 0.96025
# Early stopping, best iteration is:
# [233]	training's auc: 0.994808	valid_1's auc: 0.960992
# score:  0.8900949796472186 71.75999999999999
# 71.10400000000001
# 五折平均分数:  0.8891104386310639
